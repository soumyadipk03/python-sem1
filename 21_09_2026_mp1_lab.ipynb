# %% [markdown]
# <a href="https://colab.research.google.com/github/soumyadipk03/python-sem1/blob/main/21_09_2026_mp1_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MP-1 LAB**
# 21.09.2026

# %%
# Functions
def myfunc():
  print("Hello!")
myfunc()
print(type(myfunc))
# Out:
# Hello!
# <class 'function'>

# %%
# This func does something
x = 2.3
y = "mystr"
def doesStg(x):
  print(2*x)

doesStg(x)
doesStg(y)
x = True
doesStg(x)
y = doesStg(x)
print(y)
print(type(y))
# Out:
# 4.6
# mystrmystr
# 2
# 2
# None
# <class 'NoneType'>

# %%
# This func does something: part 2
x = 2.3
y = "mystr"
def doesStg(x):
  return(2*x, 'hi')

y = doesStg(x)
print(y)
print(type(y))
# Out:
# (4.6, 'hi')
# <class 'tuple'>

# %%
# This func does something: part 3
x = 2.3
# Function calculates 3x^2 / 1 + x^2
def doesStg(x):
  temp = x*x
  temp = temp / (1 + temp)
  temp = temp * 3
  return temp

y = doesStg(x)
print(y)
print(type(y))
# Out:
# 2.5230524642289347
# <class 'float'>

# %%
# This func does something: part 4
x = 2.3
z = 3
# Function calculates 3x^2 / 1 + x^2
def doesStg(x, y):
  temp = x*x
  temp = temp / (1 + temp)
  temp = temp * y
  return temp

y = doesStg(x, z)
print(y)
print(type(y))
# Out:
# 2.5230524642289347
# <class 'float'>

# %%
# This func does something: part 5
x = 2.3
z = 3
# Function calculates 3x^2 / 1 + x^2
def doesStg(x, y):
  temp = x*x
  temp = temp / (1 + temp)
  temp = temp * y
  return temp

stelse = [12, 13, 14]
for i in range(len(stelse)):
  y = doesStg(stelse[i], z)
  print(y)
print(type(y))
# Out:
# 2.979310344827586
# 2.9823529411764707
# 2.984771573604061
# <class 'float'>
